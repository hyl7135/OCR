# %%
# 1
posts_input = Input(shape=(64,64,3), dtype='float32', name='posts')

common = layers.Conv2D(filters= 64, kernel_size=(3,3), padding="same")(posts_input)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.MaxPool2D(pool_size=2)(common)

firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.MaxPool2D(pool_size=2)(firstLayer)

firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)

SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.MaxPool2D(pool_size=2)(SecondLayer)

SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)

ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.MaxPool2D(pool_size=2)(ThirdLayer)

ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)

firstLayer = layers.Flatten()(firstLayer)
SecondLayer = layers.Flatten()(SecondLayer)
ThirdLayer = layers.Flatten()(ThirdLayer)

# DenseCho = layers.Dense(128, activation='relu', name='DenseCho1')(x)
# DenseJung = layers.Dense(128, activation='relu', name='DenseJung1')(x)
# DenseJong = layers.Dense(128, activation='relu', name='DenseJong1')(x)


DenseCho = layers.Dense(19, activation='softmax', name='DenseCho2')(firstLayer)
DenseJung = layers.Dense(21, activation='softmax', name='DenseJung2')(SecondLayer)
DenseJong = layers.Dense(28, activation='softmax', name='DenseJong2')(ThirdLayer)

losses = {
	#"DenseCho2": "categorical_crossentropy",
	"DenseCho2": "sparse_categorical_crossentropy",
	"DenseJung2": "sparse_categorical_crossentropy",
    "DenseJong2": "sparse_categorical_crossentropy"
}

model = Model(posts_input, [DenseCho, DenseJung, DenseJong])

model.compile(loss = 'sparse_categorical_crossentropy',optimizer='adam', 
               metrics=[['accuracy'], ['accuracy'], ['accuracy']])

# %%
posts_input = Input(shape=(64,64,3), dtype='float32', name='posts')

# common = layers.Conv2D(filters= 64, kernel_size=(3,3), padding="same")(posts_input)
# common = layers.BatchNormalization()(common)
# common = layers.Activation('relu')(common)
# common = layers.MaxPool2D(pool_size=2)(common)



firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(posts_input)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.MaxPool2D(pool_size=2)(firstLayer)

firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)

SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(posts_input)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.MaxPool2D(pool_size=2)(SecondLayer)

SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)

ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(posts_input)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.MaxPool2D(pool_size=2)(ThirdLayer)

ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)

firstLayer = layers.Flatten()(firstLayer)
SecondLayer = layers.Flatten()(SecondLayer)
ThirdLayer = layers.Flatten()(ThirdLayer)

# DenseCho = layers.Dense(128, activation='relu', name='DenseCho1')(x)
# DenseJung = layers.Dense(128, activation='relu', name='DenseJung1')(x)
# DenseJong = layers.Dense(128, activation='relu', name='DenseJong1')(x)


DenseCho = layers.Dense(19, activation='softmax', name='DenseCho2')(firstLayer)
DenseJung = layers.Dense(21, activation='softmax', name='DenseJung2')(SecondLayer)
DenseJong = layers.Dense(28, activation='softmax', name='DenseJong2')(ThirdLayer)

losses = {
	#"DenseCho2": "categorical_crossentropy",
	"DenseCho2": "sparse_categorical_crossentropy",
	"DenseJung2": "sparse_categorical_crossentropy",
    "DenseJong2": "sparse_categorical_crossentropy"
}

model = Model(posts_input, [DenseCho, DenseJung, DenseJong])

model.compile(loss = 'sparse_categorical_crossentropy',optimizer='adam', 
               metrics=[['accuracy'], ['accuracy'], ['accuracy']])

# Total params: 9,698,052 (37.00 MB)

# %%
# 1
posts_input = Input(shape=(64,64,3), dtype='float32', name='posts')

common = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same")(posts_input)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.MaxPool2D(pool_size=2)(common)

firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.MaxPool2D(pool_size=2)(firstLayer)

firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)

SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.MaxPool2D(pool_size=2)(SecondLayer)

SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)

ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.MaxPool2D(pool_size=2)(ThirdLayer)

ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)

firstLayer = layers.Flatten()(firstLayer)
SecondLayer = layers.Flatten()(SecondLayer)
ThirdLayer = layers.Flatten()(ThirdLayer)

# DenseCho = layers.Dense(128, activation='relu', name='DenseCho1')(x)
# DenseJung = layers.Dense(128, activation='relu', name='DenseJung1')(x)
# DenseJong = layers.Dense(128, activation='relu', name='DenseJong1')(x)


DenseCho = layers.Dense(19, activation='softmax', name='DenseCho2')(firstLayer)
DenseJung = layers.Dense(21, activation='softmax', name='DenseJung2')(SecondLayer)
DenseJong = layers.Dense(28, activation='softmax', name='DenseJong2')(ThirdLayer)

losses = {
	#"DenseCho2": "categorical_crossentropy",
	"DenseCho2": "sparse_categorical_crossentropy",
	"DenseJung2": "sparse_categorical_crossentropy",
    "DenseJong2": "sparse_categorical_crossentropy"
}

model = Model(posts_input, [DenseCho, DenseJung, DenseJong])

model.compile(loss = 'sparse_categorical_crossentropy',optimizer='adam', 
               metrics=[['accuracy'], ['accuracy'], ['accuracy']])

#  Total params: 2,789,188 (10.64 MB)

# %%
# 1
posts_input = Input(shape=(64,64,3), dtype='float32', name='posts')

common = layers.Conv2D(filters= 64, kernel_size=(3,3), padding="same")(posts_input)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.MaxPool2D(pool_size=2)(common)

firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.MaxPool2D(pool_size=2)(firstLayer)

firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)

SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.MaxPool2D(pool_size=2)(SecondLayer)

SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)

ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.MaxPool2D(pool_size=2)(ThirdLayer)

ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)

firstLayer = layers.Flatten()(firstLayer)
SecondLayer = layers.Flatten()(SecondLayer)
ThirdLayer = layers.Flatten()(ThirdLayer)

# DenseCho = layers.Dense(128, activation='relu', name='DenseCho1')(x)
# DenseJung = layers.Dense(128, activation='relu', name='DenseJung1')(x)
# DenseJong = layers.Dense(128, activation='relu', name='DenseJong1')(x)


DenseCho = layers.Dense(19, activation='softmax', name='DenseCho2')(firstLayer)
DenseJung = layers.Dense(21, activation='softmax', name='DenseJung2')(SecondLayer)
DenseJong = layers.Dense(28, activation='softmax', name='DenseJong2')(ThirdLayer)

losses = {
	#"DenseCho2": "categorical_crossentropy",
	"DenseCho2": "sparse_categorical_crossentropy",
	"DenseJung2": "sparse_categorical_crossentropy",
    "DenseJong2": "sparse_categorical_crossentropy"
}

model = Model(posts_input, [DenseCho, DenseJung, DenseJong])

model.compile(loss = 'sparse_categorical_crossentropy',optimizer='adam', 
               metrics=[['accuracy'], ['accuracy'], ['accuracy']])

# Total params: 2,861,508 (10.92 MB)

# %%
# 1
posts_input = Input(shape=(64,64,3), dtype='float32', name='posts')

common = layers.Conv2D(filters= 64, kernel_size=(3,3), padding="same")(posts_input)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.MaxPool2D(pool_size=2)(firstLayer)

firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)

SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.MaxPool2D(pool_size=2)(SecondLayer)

SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)

ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.MaxPool2D(pool_size=2)(ThirdLayer)

ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)

firstLayer = layers.Flatten()(firstLayer)
SecondLayer = layers.Flatten()(SecondLayer)
ThirdLayer = layers.Flatten()(ThirdLayer)

# DenseCho = layers.Dense(128, activation='relu', name='DenseCho1')(x)
# DenseJung = layers.Dense(128, activation='relu', name='DenseJung1')(x)
# DenseJong = layers.Dense(128, activation='relu', name='DenseJong1')(x)


DenseCho = layers.Dense(19, activation='softmax', name='DenseCho2')(firstLayer)
DenseJung = layers.Dense(21, activation='softmax', name='DenseJung2')(SecondLayer)
DenseJong = layers.Dense(28, activation='softmax', name='DenseJong2')(ThirdLayer)

losses = {
	#"DenseCho2": "categorical_crossentropy",
	"DenseCho2": "sparse_categorical_crossentropy",
	"DenseJung2": "sparse_categorical_crossentropy",
    "DenseJong2": "sparse_categorical_crossentropy"
}

model = Model(posts_input, [DenseCho, DenseJung, DenseJong])

model.compile(loss = 'sparse_categorical_crossentropy',optimizer='adam', 
               metrics=[['accuracy'], ['accuracy'], ['accuracy']])

# Total params: 2,861,508 (10.92 MB)

# %%
# 1
posts_input = Input(shape=(64,64,3), dtype='float32', name='posts')

common = layers.Conv2D(filters= 64, kernel_size=(3,3), padding="same")(posts_input)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)
common = layers.Conv2D(filters= 256, kernel_size=(3,3), padding="same")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.MaxPool2D(pool_size=2)(firstLayer)

firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)

SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.MaxPool2D(pool_size=2)(SecondLayer)

SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)

ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.MaxPool2D(pool_size=2)(ThirdLayer)

ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)

firstLayer = layers.Flatten()(firstLayer)
SecondLayer = layers.Flatten()(SecondLayer)
ThirdLayer = layers.Flatten()(ThirdLayer)

# DenseCho = layers.Dense(128, activation='relu', name='DenseCho1')(x)
# DenseJung = layers.Dense(128, activation='relu', name='DenseJung1')(x)
# DenseJong = layers.Dense(128, activation='relu', name='DenseJong1')(x)


DenseCho = layers.Dense(19, activation='softmax', name='DenseCho2')(firstLayer)
DenseJung = layers.Dense(21, activation='softmax', name='DenseJung2')(SecondLayer)
DenseJong = layers.Dense(28, activation='softmax', name='DenseJong2')(ThirdLayer)

losses = {
	#"DenseCho2": "categorical_crossentropy",
	"DenseCho2": "sparse_categorical_crossentropy",
	"DenseJung2": "sparse_categorical_crossentropy",
    "DenseJong2": "sparse_categorical_crossentropy"
}

model = Model(posts_input, [DenseCho, DenseJung, DenseJong])

model.compile(loss = 'sparse_categorical_crossentropy',optimizer='adam', 
               metrics=[['accuracy'], ['accuracy'], ['accuracy']])
# Total params: 1,707,716 (6.51 MB)
# handwriteModeling1_3.weights.h5
#

# %%
# 1
posts_input = Input(shape=(64,64,3), dtype='float32', name='posts')

common = layers.Conv2D(filters= 64, kernel_size=(3,3), padding="same")(posts_input)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

Vowelbranch = layers.Conv2D(filters= 256, kernel_size=(3,3), padding="same")(common)
Vowelbranch = layers.BatchNormalization()(Vowelbranch)
Vowelbranch = layers.Activation('relu')(Vowelbranch)
Vowelbranch = layers.SpatialDropout2D(0.2)(Vowelbranch)
Vowelbranch = layers.MaxPool2D(pool_size=2)(Vowelbranch)

common = layers.Conv2D(filters= 256, kernel_size=(3,3), padding="same")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.MaxPool2D(pool_size=2)(firstLayer)

firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)

SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(Vowelbranch)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.MaxPool2D(pool_size=2)(SecondLayer)

SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)

ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.MaxPool2D(pool_size=2)(ThirdLayer)

ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)

firstLayer = layers.Flatten()(firstLayer)
SecondLayer = layers.Flatten()(SecondLayer)
ThirdLayer = layers.Flatten()(ThirdLayer)

# DenseCho = layers.Dense(128, activation='relu', name='DenseCho1')(x)
# DenseJung = layers.Dense(128, activation='relu', name='DenseJung1')(x)
# DenseJong = layers.Dense(128, activation='relu', name='DenseJong1')(x)


DenseCho = layers.Dense(19, activation='softmax', name='DenseCho2')(firstLayer)
DenseJung = layers.Dense(21, activation='softmax', name='DenseJung2')(SecondLayer)
DenseJong = layers.Dense(28, activation='softmax', name='DenseJong2')(ThirdLayer)

losses = {
	#"DenseCho2": "categorical_crossentropy",
	"DenseCho2": "sparse_categorical_crossentropy",
	"DenseJung2": "sparse_categorical_crossentropy",
    "DenseJong2": "sparse_categorical_crossentropy"
}

model = Model(posts_input, [DenseCho, DenseJung, DenseJong])

model.compile(loss = 'sparse_categorical_crossentropy',optimizer='adam', 
               metrics=[['accuracy'], ['accuracy'], ['accuracy']])
#  Total params: 2,003,908 (7.64 MB)
# handwriteModeling1_4.weights.h5

# %%
# 1
posts_input = Input(shape=(64,64,GRAY_SCALE), dtype='float32', name='posts')

# common layer 1

common = layers.Conv2D(filters= 32, kernel_size=(3,3), padding="same")(posts_input)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
# common = layers.SpatialDropout2D(0.2)(common)
# common = layers.MaxPool2D(pool_size=2)(common)

#sigmoidLayer = tf.math.sigmoid(common)
#sigmoidLayer = tf.sigmoid(common)
#sigmoidLayer = tf.nn.sigmoid(common)
#common = layers.multiply()([common, sigmoidLayer])


# common layer 2

common = layers.Conv2D(filters= 64, kernel_size=(3,3), padding="same")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

# Vowelbranch layer 1

Vowelbranch = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same")(common)
Vowelbranch = layers.BatchNormalization()(Vowelbranch)
Vowelbranch = layers.Activation('relu')(Vowelbranch)
Vowelbranch = layers.SpatialDropout2D(0.2)(Vowelbranch)
Vowelbranch = layers.MaxPool2D(pool_size=2)(Vowelbranch)

# Vowelbranch layer 2

Vowelbranch = layers.Conv2D(filters= 256, kernel_size=(3,3), padding="same")(Vowelbranch)
Vowelbranch = layers.BatchNormalization()(Vowelbranch)
Vowelbranch = layers.Activation('relu')(Vowelbranch)
Vowelbranch = layers.SpatialDropout2D(0.2)(Vowelbranch)
Vowelbranch = layers.MaxPool2D(pool_size=2)(Vowelbranch)

common = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

common = layers.Conv2D(filters= 256, kernel_size=(3,3), padding="same")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.MaxPool2D(pool_size=2)(firstLayer)

firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)

SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(Vowelbranch)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.MaxPool2D(pool_size=2)(SecondLayer)

SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)

ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.MaxPool2D(pool_size=2)(ThirdLayer)

ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)

firstLayer = layers.Flatten()(firstLayer)
SecondLayer = layers.Flatten()(SecondLayer)
ThirdLayer = layers.Flatten()(ThirdLayer)

# DenseCho = layers.Dense(128, activation='relu', name='DenseCho1')(x)
# DenseJung = layers.Dense(128, activation='relu', name='DenseJung1')(x)
# DenseJong = layers.Dense(128, activation='relu', name='DenseJong1')(x)


DenseCho = layers.Dense(19, activation='softmax', name='DenseCho2')(firstLayer)
DenseJung = layers.Dense(21, activation='softmax', name='DenseJung2')(SecondLayer)
DenseJong = layers.Dense(28, activation='softmax', name='DenseJong2')(ThirdLayer)

losses = {
	#"DenseCho2": "categorical_crossentropy",
	"DenseCho2": "sparse_categorical_crossentropy",
	"DenseJung2": "sparse_categorical_crossentropy",
    "DenseJong2": "sparse_categorical_crossentropy"
}

model = Model(posts_input, [DenseCho, DenseJung, DenseJong])

model.compile(loss = 'sparse_categorical_crossentropy',optimizer='adam', 
               metrics=[['accuracy'], ['accuracy'], ['accuracy']])

# Total params: 1,678,212 (6.40 MB)

# %%
# 1
posts_input = Input(shape=(64,64,3), dtype='float32', name='posts')

# common layer 1

common = layers.Conv2D(filters= 32, kernel_size=(3,3), padding="same")(posts_input)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
# common = layers.SpatialDropout2D(0.2)(common)
# common = layers.MaxPool2D(pool_size=2)(common)

#sigmoidLayer = tf.math.sigmoid(common)
#sigmoidLayer = tf.sigmoid(common)
#sigmoidLayer = tf.nn.sigmoid(common)
#common = layers.multiply()([common, sigmoidLayer])


# common layer 2

common = layers.Conv2D(filters= 64, kernel_size=(3,3), padding="same")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

# Vowelbranch layer 1

Vowelbranch = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same")(common)
Vowelbranch = layers.BatchNormalization()(Vowelbranch)
Vowelbranch = layers.Activation('relu')(Vowelbranch)
Vowelbranch = layers.SpatialDropout2D(0.2)(Vowelbranch)
Vowelbranch = layers.MaxPool2D(pool_size=2)(Vowelbranch)

# Vowelbranch layer 2

Vowelbranch = layers.Conv2D(filters= 256, kernel_size=(3,3), padding="same")(Vowelbranch)
Vowelbranch = layers.BatchNormalization()(Vowelbranch)
Vowelbranch = layers.Activation('relu')(Vowelbranch)
Vowelbranch = layers.SpatialDropout2D(0.2)(Vowelbranch)
Vowelbranch = layers.MaxPool2D(pool_size=2)(Vowelbranch)

common = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

common = layers.Conv2D(filters= 256, kernel_size=(3,3), padding="same")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.MaxPool2D(pool_size=2)(firstLayer)

firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)

SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(Vowelbranch)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.MaxPool2D(pool_size=2)(SecondLayer)

ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(common)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.MaxPool2D(pool_size=2)(ThirdLayer)

SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)

ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)

#MultiLayer = layers.multiply()([SecondLayer, ThirdLayer])
MultiLayer = layers.multiply([SecondLayer, ThirdLayer])

firstLayer = layers.Flatten()(firstLayer)
SecondLayer = layers.Flatten()(MultiLayer)
ThirdLayer = SecondLayer
#SecondLayer = layers.Flatten()(SecondLayer)
#ThirdLayer = layers.Flatten()(ThirdLayer)

# DenseCho = layers.Dense(128, activation='relu', name='DenseCho1')(x)
# DenseJung = layers.Dense(128, activation='relu', name='DenseJung1')(x)
# DenseJong = layers.Dense(128, activation='relu', name='DenseJong1')(x)


DenseCho = layers.Dense(19, activation='softmax', name='DenseCho2')(firstLayer)
DenseJung = layers.Dense(21, activation='softmax', name='DenseJung2')(SecondLayer)
DenseJong = layers.Dense(28, activation='softmax', name='DenseJong2')(ThirdLayer)

losses = {
	#"DenseCho2": "categorical_crossentropy",
	"DenseCho2": "sparse_categorical_crossentropy",
	"DenseJung2": "sparse_categorical_crossentropy",
    "DenseJong2": "sparse_categorical_crossentropy"
}

model = Model(posts_input, [DenseCho, DenseJung, DenseJong])

model.compile(loss = 'sparse_categorical_crossentropy',optimizer='adam', 
               metrics=[['accuracy'], ['accuracy'], ['accuracy']])

#  Total params: 1,678,212 (6.40 MB)

# %%
# 1
posts_input = Input(shape=(64,64,3), dtype='float32', name='posts')




# common layer 1

common = layers.Conv2D(filters= 32, kernel_size=(3,3), padding="same", name = "common1")(posts_input)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
# common layer 2

common = layers.Conv2D(filters= 64, kernel_size=(3,3), padding="same", name = "common2")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)

lastCl = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same", name="lastCl_3")(common)
lastCl = layers.BatchNormalization()(common)
lastCl = layers.Activation('relu')(common)
lastCl = layers.SpatialDropout2D(0.2)(lastCl)
lastCl = layers.MaxPool2D(pool_size=2)(lastCl)

lastCl = layers.Conv2D(filters= 256, kernel_size=(3,3), padding="same", name="lastCl_4")(lastCl)
lastCl = layers.BatchNormalization()(lastCl)
lastCl = layers.Activation('relu')(lastCl)
lastCl = layers.SpatialDropout2D(0.2)(lastCl)
lastCl = layers.MaxPool2D(pool_size=2)(lastCl)

common = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same", name = "common3")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

common = layers.Conv2D(filters= 256, kernel_size=(3,3), padding="same", name = "common4")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same", name = "first1")(common)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)
firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", name = "first2")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)
firstLayer = layers.AveragePooling2D(pool_size=2)(firstLayer)
firstLayer = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same", name = "first3")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)
firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", name = "first4")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)
firstLayer = layers.AveragePooling2D(pool_size=2)(firstLayer)
firstLayer = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same", name = "first5")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)

SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same", name = "second1")(lastCl)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)
SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", name = "second2")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)
SecondLayer = layers.AveragePooling2D(pool_size=2)(SecondLayer)
SecondLayer = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same", name = "second3")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)
SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", name = "second4")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)
SecondLayer = layers.AveragePooling2D(pool_size=2)(SecondLayer)
SecondLayer = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same", name = "second5")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)

ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same", name = "third1")(lastCl)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", name = "third2")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)
ThirdLayer = layers.AveragePooling2D(pool_size=2)(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same", name = "third3")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", name = "third4")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)
ThirdLayer = layers.AveragePooling2D(pool_size=2)(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same", name = "third5")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)

firstLayer = layers.Flatten()(firstLayer)
SecondLayer = layers.Flatten()(SecondLayer)
ThirdLayer = layers.Flatten()(ThirdLayer)

# DenseCho = layers.Dense(128, activation='relu', name='DenseCho1')(x)
# DenseJung = layers.Dense(128, activation='relu', name='DenseJung1')(x)
# DenseJong = layers.Dense(128, activation='relu', name='DenseJong1')(x)


DenseCho = layers.Dense(19, activation='softmax', name='DenseCho2')(firstLayer)
DenseJung = layers.Dense(21, activation='softmax', name='DenseJung2')(SecondLayer)
DenseJong = layers.Dense(28, activation='softmax', name='DenseJong2')(ThirdLayer)

losses = {
	#"DenseCho2": "categorical_crossentropy",
	"DenseCho2": "sparse_categorical_crossentropy",
	"DenseJung2": "sparse_categorical_crossentropy",
    "DenseJong2": "sparse_categorical_crossentropy"
}

model = Model(posts_input, [DenseCho, DenseJung, DenseJong])

model.compile(loss = 'sparse_categorical_crossentropy',optimizer='adam', 
               metrics=[['accuracy'], ['accuracy'], ['accuracy']])

# Total params: 1,678,212 (6.40 MB)

# %%
# 1
posts_input = Input(shape=(64,64,3), dtype='float32', name='posts')

#branch
branch = layers.Conv2D(filters= 32, kernel_size=(3,3), padding="same")(posts_input)
branch = layers.BatchNormalization()(branch)
branch = layers.Activation('relu')(branch)

branch = layers.Conv2D(filters= 64, kernel_size=(3,3), padding="same")(branch)
branch = layers.BatchNormalization()(branch)
branch = layers.Activation('relu')(branch)
branch = layers.SpatialDropout2D(0.2)(branch)

branch = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same")(branch)
branch = layers.BatchNormalization()(branch)
branch = layers.Activation('relu')(branch)
branch = layers.SpatialDropout2D(0.2)(branch)
branch = layers.MaxPool2D(pool_size=2)(branch)

branch = layers.Conv2D(filters= 256, kernel_size=(3,3), padding="same")(branch)
branch = layers.BatchNormalization()(branch)
branch = layers.Activation('relu')(branch)
branch = layers.SpatialDropout2D(0.2)(branch)
branch = layers.MaxPool2D(pool_size=2)(branch)

branch = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same")(branch)
branch = layers.BatchNormalization()(branch)
branch = layers.SpatialDropout2D(0.2)(branch)
branch = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same")(branch)
branch = layers.BatchNormalization()(branch)
branch = layers.SpatialDropout2D(0.2)(branch)
branch = layers.AveragePooling2D(pool_size=2)(branch)
branch = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same")(branch)
branch = layers.BatchNormalization()(branch)
branch = layers.SpatialDropout2D(0.2)(branch)


# common layer 1

common = layers.Conv2D(filters= 32, kernel_size=(3,3), padding="same", name = "common1")(posts_input)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
# common layer 2

common = layers.Conv2D(filters= 64, kernel_size=(3,3), padding="same", name = "common2")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)

lastCl = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same", name="lastCl_3")(common)
lastCl = layers.BatchNormalization()(common)
lastCl = layers.Activation('relu')(common)
lastCl = layers.SpatialDropout2D(0.2)(lastCl)
lastCl = layers.MaxPool2D(pool_size=2)(lastCl)

lastCl = layers.Conv2D(filters= 256, kernel_size=(3,3), padding="same", name="lastCl_4")(lastCl)
lastCl = layers.BatchNormalization()(lastCl)
lastCl = layers.Activation('relu')(lastCl)
lastCl = layers.SpatialDropout2D(0.2)(lastCl)
lastCl = layers.MaxPool2D(pool_size=2)(lastCl)

common = layers.Conv2D(filters= 128, kernel_size=(3,3), padding="same", name = "common3")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

common = layers.Conv2D(filters= 256, kernel_size=(3,3), padding="same", name = "common4")(common)
common = layers.BatchNormalization()(common)
common = layers.Activation('relu')(common)
common = layers.SpatialDropout2D(0.2)(common)
common = layers.MaxPool2D(pool_size=2)(common)

firstLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same", name = "first1")(common)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)
firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", name = "first2")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)
firstLayer = layers.AveragePooling2D(pool_size=2)(firstLayer)
firstLayer = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same", name = "first3")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)

firstLayer = layers.multiply([firstLayer, branch])

firstLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", name = "first4")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)
firstLayer = layers.AveragePooling2D(pool_size=2)(firstLayer)
firstLayer = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same", name = "first5")(firstLayer)
firstLayer = layers.BatchNormalization()(firstLayer)
firstLayer = layers.SpatialDropout2D(0.2)(firstLayer)

SecondLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same", name = "second1")(lastCl)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)
SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", name = "second2")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)
SecondLayer = layers.AveragePooling2D(pool_size=2)(SecondLayer)
SecondLayer = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same", name = "second3")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)

SecondLayer = layers.multiply([SecondLayer, branch])

SecondLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", name = "second4")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)
SecondLayer = layers.AveragePooling2D(pool_size=2)(SecondLayer)
SecondLayer = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same", name = "second5")(SecondLayer)
SecondLayer = layers.BatchNormalization()(SecondLayer)
SecondLayer = layers.SpatialDropout2D(0.2)(SecondLayer)

ThirdLayer = layers.Conv2D(filters = 128, kernel_size=(3,3), padding="same", name = "third1")(lastCl)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", name = "third2")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)
ThirdLayer = layers.AveragePooling2D(pool_size=2)(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same", name = "third3")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)

ThirdLayer = layers.multiply([ThirdLayer, branch])

ThirdLayer = layers.Conv2D(filters = 64, kernel_size=(3,3), padding="same", name = "third4")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)
ThirdLayer = layers.AveragePooling2D(pool_size=2)(ThirdLayer)
ThirdLayer = layers.Conv2D(filters = 32, kernel_size=(3,3), padding="same", name = "third5")(ThirdLayer)
ThirdLayer = layers.BatchNormalization()(ThirdLayer)
ThirdLayer = layers.SpatialDropout2D(0.2)(ThirdLayer)

firstLayer = layers.Flatten()(firstLayer)
SecondLayer = layers.Flatten()(SecondLayer)
ThirdLayer = layers.Flatten()(ThirdLayer)

# DenseCho = layers.Dense(128, activation='relu', name='DenseCho1')(x)
# DenseJung = layers.Dense(128, activation='relu', name='DenseJung1')(x)
# DenseJong = layers.Dense(128, activation='relu', name='DenseJong1')(x)


DenseCho = layers.Dense(19, activation='softmax', name='DenseCho2')(firstLayer)
DenseJung = layers.Dense(21, activation='softmax', name='DenseJung2')(SecondLayer)
DenseJong = layers.Dense(28, activation='softmax', name='DenseJong2')(ThirdLayer)

losses = {
	#"DenseCho2": "categorical_crossentropy",
	"DenseCho2": "sparse_categorical_crossentropy",
	"DenseJung2": "sparse_categorical_crossentropy",
    "DenseJong2": "sparse_categorical_crossentropy"
}

model = Model(posts_input, [DenseCho, DenseJung, DenseJong])

model.compile(loss = 'sparse_categorical_crossentropy',optimizer='adam', 
               metrics=[['accuracy'], ['accuracy'], ['accuracy']])

# Total params: 1,678,212 (6.40 MB)
